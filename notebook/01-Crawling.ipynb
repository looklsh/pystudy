# %% [markdown]
# # Headline 1
# ## headline 2
#
# - 아이템 1
# - 아이템 2
#     - 아이템 2-1
#     - 아이템 2-2

# %%
# 수집대상 url
url = "http://www.gutenberg.org/cache/epub/12429/pg12429.txt"
# urllib.request 객체필요
import urllib.request
# 페이지 데이터 가져오기: urlopen
page = urllib.request.urlopen(url)
print(page, type(page))
# 페이지의 텍스트 불러오기: read
page_text = page.read().decode("utf-8")
#print("page text:", page_text)
# 디코딩 :decode()
print(page_text[:100])
# Out:
# <http.client.HTTPResponse object at 0x000001FA92F65488> <class 'http.client.HTTPResponse'>
# ﻿The Project Gutenberg EBook of The Last Leaf, by James Kendall Hosmer
#
# This eBook is for the use

# %%
# #012345 -> 뭔가의 코드일 것이다
import re

#아마도 이것은 뭔가의 코드일 것이다
iter = re.finditer(r"#[0-9]+", page_text)
# finditer ->
# SRE_MATCH 객체의 리스트로 저장
# 순회할 수 있다
for code in iter:
    print("code:", code.group())
# Out:
# code: #12429
# code: #10000
# code: #10000

# %%
http://www.gutenberg.org/cache/epub/12429/pg12429.txt
- 데이터를 크롤링 하여 정규식으로 몇 가지 사실을 알아내 봅시다
# Out:
#   File "<ipython-input-3-760df02e7802>", line 1
#     http://www.gutenberg.org/cache/epub/12429/pg12429.txt
#           ^
# SyntaxError: invalid syntax

# %%
# 수집한 데이터가 Last Leaf니까
# leaf라는 단어가 얼마나 나오는지
print("leaf:", re.findall(r"leaf", page_text))
# leaves는 얼마나 나오나(복수형)
print("leaves", re.findall(r"leaves", page_text))
# Leaf or Leaves는 얼마나 나오나
print("Leaf or Leaves", re.findall(r"Leaf|Leaves", page_text))

# 한 번에 뽑아 낼 수 있는 패턴은 없을까?
print(re.findall("leaf|leaves", page_text, re.IGNORECASE))

# 첫글자가 대문자인 경우 -> 고유명사이거나 문장의 첫 단어일 가능성
p = re.compile(r"\b[A-Z]{1}[a-z]+")
iter = re.finditer(p, page_text)

#for word in iter:
#    print("첫 글자가 대문자인 단어:", word.group())
    
# 첫 글자가 대문자인 단어의 List 생성
words = [item.group().strip() for item in iter]
print("words:", words)

# 정렬
words.sort()
#print(words)
# 중복 제거
words = list(set(words))
print("첫 글자가 대문자인 단어의 개수:", len(words))
# Out:
# leaf: ['leaf']
# leaves ['leaves', 'leaves', 'leaves', 'leaves']
# Leaf or Leaves ['Leaf', 'Leaf', 'Leaf', 'Leaf', 'Leaf', 'Leaf', 'Leaves', 'Leaf', 'Leaf']
# ['Leaf', 'Leaf', 'LEAF', 'Leaf', 'leaves', 'leaves', 'Leaf', 'Leaf', 'leaves', 'Leaf', 'leaf', 'Leaves', 'leaves', 'Leaf', 'Leaf', 'LEAF']
# words: ['The', 'Project', 'Gutenberg', 'The', 'Last', 'Leaf', 'James', 'Kendall', 'Hosmer', 'This', 'You', 'Project', 'Gutenberg', 'License', 'Title', 'The', 'Last', 'Leaf', 'Observations', 'Seventy', 'Five', 'Years', 'Men', 'Events', 'America', 'Europe', 'Author', 'James', 'Kendall', 'Hosmer', 'Release', 'Date', 'May', 'Language', 'English', 'Produced', 'Ted', 'Garvin', 'Bill', 'Hershey', 'Distributed', 'Proofreaders', 'The', 'Last', 'Leaf', 'Observations', 'Seventy', 'Years', 'Men', 'Events', 'America', 'Europe', 'By', 'James', 'Kendall', 'Hosmer', 'Member', 'Minnesota', 'Historical', 'Society', 'Corresponding', 'Member', 'Massachusetts', 'Historical', 'Society', 'Colonial', 'Society', 'Massachusetts', 'Author', 'Short', 'History', 'German', 'Literature', 'The', 'Story', 'Jews', 'Lives', 'Samuel', 'Adams', 'Thomas', 'Jefferson', 'Sir', 'Henry', 'Vane', 'Standing', 'Can', 'We', 'Homer', 'In', 'Dr', 'Holmes', 'Totters', 'With', 'He', 'His', 'Were', 'The', 'To', 'In', 'Dr', 'Holmes', 'At', 'If', 'The', 'We', 'As', 'Retiring', 'Satanic', 'Jobs', 'Lord', 'Lord', 'My', 'Monthly', 'New', 'York', 'Post', 'Boston', 'My', 'Go', 'October', 'Tippecanoe', 'Tyler', 'Millard', 'Fillmore', 'Abraham', 'Lincoln', 'Church', 'Stephen', 'Douglas', 'Daniel', 'Webster', 'William', 'Seward', 'Edward', 'Everett', 'Robert', 'Winthrop', 'Charles', 'Sumner', 'John', 'Andrew', 'Grant', 'Philip', 'Sheridan', 'George', 'Meade', 'Sherman', 'Jacob', 'Cox', 'Banks', 'Butler', 'John', 'Pope', 'Henry', 'Slocum', 'Howard', 'Rufus', 'Saxton', 'James', 'Wilson', 'Sherman', 'Horatio', 'Wright', 'Isaac', 'Stevens', 'Harvard', 'Soldiers', 'Bartlett', 'Charles', 'Lowell', 'Francis', 'Barlow', 'Horace', 'Mann', 'The', 'New', 'Wrinkle', 'Sweetbrier', 'Dramatics', 'Schools', 'Germany', 'France', 'England', 'Antioch', 'College', 'Prussia', 'Militarism', 'Schools', 'Universities', 'Home', 'Sepulchre', 'The', 'Hohenzollern', 'Lineage', 'Kaiser', 'Wilhelm', 'Grosse', 'The', 'Emperor', 'Frederick', 'Wilhelm', 'Francis', 'Joseph', 'Austria', 'King', 'Ludwig', 'Bavaria', 'Munich', 'War', 'Deserted', 'Switzerland', 'France', 'Arms', 'Paris', 'Verge', 'Siege', 'George', 'Bancroft', 'Justin', 'Winsor', 'John', 'Fiske', 'Sir', 'Richard', 'Garnett', 'Gardiner', 'Freeman', 'Goldwin', 'Smith', 'James', 'Bryce', 'The', 'House', 'Commons', 'Lord', 'Randolph', 'Churchill', 'Gladstone', 'Makers', 'History', 'Von', 'Treitschke', 'Ernst', 'Curtius', 'Leopold', 'Ranke', 'Theodor', 'Mommsen', 'Lepsius', 'Hermann', 'Grimm', 'Henry', 'Longfellow', 'Oliver', 'Wendell', 'Holmes', 'James', 'Russell', 'Lowell', 'The', 'Town', 'Concord', 'Henry', 'Thoreau', 'Louisa', 'Alcott', 'Nathaniel', 'Hawthorne', 'Ralph', 'Waldo', 'Emerson', 'Phillips', 'Brooks', 'German', 'Scientists', 'Kirchoff', 'Physicist', 'Bunsen', 'Chemist', 'Helmholtz', 'American', 'Scientists', 'Simon', 'Newcomb', 'Asa', 'Gray', 'Louis', 'Agassiz', 'Alexander', 'Agassiz', 'William', 'Grey', 'Ninth', 'Earl', 'Stamford', 'The', 'Franciscan', 'Salzburg', 'The', 'Berlin', 'Dancer', 'Visits', 'Old', 'Battle', 'Eupeptic', 'Musings', 'The', 'Last', 'Leaf', 'Buffalo', 'New', 'York', 'Andrew', 'Jackson', 'Massachusetts', 'Erie', 'Canal', 'Speaking', 'Then', 'My', 'For', 'Tippecanoe', 'Tyler', 'Four', 'Harry', 'Clay', 'Old', 'Kentucky', 'My', 'Millard', 'Fillmore', 'Nathan', 'Hall', 'Postmaster', 'General', 'Hiram', 'Barton', 'Fillmore', 'President', 'Say', 'Fillmore', 'Fugitive', 'Slave', 'Bill', 'That', 'Civil', 'War', 'Had', 'Fillmore', 'Union', 'The', 'North', 'Union', 'Moreover', 'West', 'Mississippi', 'South', 'East', 'West', 'East', 'As', 'Union', 'Had', 'Fillmore', 'As', 'Mr', 'Fillmore', 'The', 'Mr', 'Fillmore', 'Navy', 'Government', 'Great', 'Lakes', 'To', 'But', 'He', 'The', 'Mr', 'Fillmore', 'In', 'Fugitive', 'Slave', 'Law', 'He', 'President', 'He', 'He', 'Fillmore', 'His', 'His', 'Abby', 'They', 'In', 'No', 'Fillmore', 'He', 'Rhodes', 'When', 'February', 'Abraham', 'Lincoln', 'Washington', 'Buffalo', 'Saturday', 'Sunday', 'Mr', 'L ...
# 첫 글자가 대문자인 단어의 개수: 1928
